# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/fahadch/ibm class projects/.git/

# %% [markdown]
# !git add README.md

# %%
 # !git add README.md
# Out:
# fatal: pathspec 'README.md' did not match any files

# %%
echo "# ibm-class-projects" >> README.md

# %%
# !git init
# Out:
# Reinitialized existing Git repository in C:/Users/fahadch/ibm class projects/.git/

# %%
! add README.md
# Out:
# 'add' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !git add README.md

# %%
# !git commit -m "first commit"
# Out:
# [master (root-commit) 34ade57] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md

# %%
git branch -M main
# Out:
#   Cell In[8], line 1
#     git branch -M main
#         ^
# SyntaxError: invalid syntax

# %%
# !git branch -M main
